# %% [markdown]
# # Execução: Bootstrap Eval Temporal KG Rev3 (DyFO)
# Este notebook foi gerado para executar o experimento no Google Colab.
#
# **Instruções:**
# 1. Comprima a pasta do projeto como `DyFO.zip` e faça o upload para a raiz do seu Google Drive (`Meu Drive`).
# 2. Execute as células abaixo em ordem.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Preparação do Ambiente
# Copiaremos o `.zip` do Drive para o Colab (para maior velocidade de leitura/escrita) e instalaremos as dependências.

# %%
# Descompacta o projeto (sobrescrevendo se já existir)
# !unzip -q -o "/content/drive/MyDrive/DyFO.zip" -d "/content/"

# Entra na pasta descompactada
# %cd "/content/DyFO"

# Instala os pacotes do requirements.txt e o próprio pacote em modo iterativo
# !pip install -r requirements.txt
# !pip install -e .

# %% [markdown]
# ## Execução do Script

# %%
# !python scripts/run_bootstrap_eval_temporal_kg_rev3.py --variants tgn tgat roland gat_static --n_tickers 50 --epochs 100 --n_bootstrap 5000

# %% [markdown]
# ## Salvando os Resultados
# Após a execução, copie a pasta `results/` e/o `logs/` de volta para o Drive, caso queira preservá-los permanentemente.

# %%
import shutil
import os

# Exemplo: Copiando a pasta results para o drive
if os.path.exists('/content/DyFO/results'):
    # !cp -r /content/DyFO/results /content/drive/MyDrive/DyFO_results
    print("Resultados copiados para Meu Drive/DyFO_results")

if os.path.exists('/content/DyFO/logs'):
    # !cp -r /content/DyFO/logs /content/drive/MyDrive/DyFO_logs
    print("Logs copiados para Meu Drive/DyFO_logs")
